# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('adult.csv')
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # 1.Display Top 30 Rows of The Dataset

# %%
data.head(30)
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0    25           Private  226802          11th                7
# 1    38           Private   89814       HS-grad                9
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 4    18                 ?  103497  Some-college               10
# 5    34           Private  198693          10th                6
# 6    29                 ?  227026       HS-grad                9
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 8    24           Private  369667  Some-college               10
# 9    55           Private  104996       7th-8th                4
# 10   65           Private  184454       HS-grad                9
# 11   36       Federal-gov  212465     Bachelors               13
# 12   26           Private   82091       HS-grad                9
# ...

# %% [markdown]
# # 2. Check Last 30 Rows of The Dataset

# %%
data.tail(30)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48812   30                 ?   33811     Bachelors               13
# 48813   34           Private  204461     Doctorate               16
# 48814   54           Private  337992     Bachelors               13
# 48815   37           Private  179137  Some-college               10
# 48816   22           Private  325033          12th                8
# 48817   34           Private  160216     Bachelors               13
# 48818   30           Private  345898       HS-grad                9
# 48819   38           Private  139180     Bachelors               13
# 48820   71                 ?  287372     Doctorate               16
# 48821   45         State-gov  252208       HS-grad                9
# 48822   41                 ?  202822       HS-grad                9
# 48823   72                 ?  129912       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# ...

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (48842, 15)

# %%
print("Number of rows n data_set is ",data.shape[0])
# Out:
# Number of rows n data_set is  48842

# %%
print("number of columns in data_set is ", data.shape[1])
# Out:
# number of columns in data_set is  15

# %% [markdown]
# # 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # 5. Fetch Random Sample From the Dataset (50%)

# %%
# without useing random_state its returned different results every time you run your code 
data.sample(frac=0.50)
# Out:
#        age    workclass  fnlwgt     education  educational-num  \
# 13355   21      Private  270043  Some-college               10
# 29352   46      Private  264210  Some-college               10
# 37160   53  Federal-gov  271544       HS-grad                9
# 7618    37      Private  216129       HS-grad                9
# 33102   31      Private  169583       HS-grad                9
# ...    ...          ...     ...           ...              ...
# 17844   51      Private  154342       7th-8th                4
# 25411   40      Private  259307       Masters               14
# 5614    25    Local-gov  315287  Some-college               10
# 10250   39      Private  240468       HS-grad                9
# 40034   41      Private  353541       HS-grad                9
#
#            marital-status         occupation    relationship   race  gender  \
# 13355       Never-married       Tech-support       Own-child  White  Female
# ...

# %%
#if you set the random_state to a specific value, you will get the same "random" results every time you run your code. 
data.sample(frac=0.50,random_state=101)
# Out:
#        age         workclass  fnlwgt   education  educational-num  \
# 30658   22           Private  106700  Assoc-acdm               12
# 25493   23       Federal-gov  320294     HS-grad                9
# 11136   38           Private   79483     HS-grad                9
# 3814    45           Private  160440     HS-grad                9
# 743     46  Self-emp-not-inc  315984     HS-grad                9
# ...    ...               ...     ...         ...              ...
# 28575   38           Private  195744   Bachelors               13
# 46452   45           Private   80430     HS-grad                9
# 43134   46           Private   33109     HS-grad                9
# 3026    37  Self-emp-not-inc  183127     HS-grad                9
# 42889   60           Private  166330     HS-grad                9
#
#            marital-status       occupation   relationship   race  gender  \
# 30658       Never-married     Adm-clerical      Own-child  White  Female
# ...

# %% [markdown]
# # 6.Check Null Values In The Dataset

# %%
data.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # 7.Perform Data Cleaning [ Replace '?' with NaN ]

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.isin(['?'])
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False       True   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
data.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
import numpy as np 
data['workclass'].replace('?',np.nan,inplace=True)

# %%
data['occupation'].replace('?',np.nan,inplace=True)

# %%
data['native-country'].replace('?',np.nan,inplace=True)

# %%
data.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # 8. Drop all The Missing Values

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.isnull().sum()*100/len(data)
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
#dropna method is use to drop nan value in the data 
data.dropna(how="any",inplace=True)

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
data.shape
# Out:
# (45222, 15)

# %%
print("total drop rows those contain nan value:-",48842-45222)
# Out:
# total drop rows those contain nan value:- 3620

# %% [markdown]
# #  9. Check For Duplicate Data and Drop Them

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
dup=data.duplicated().any()

# %%
print("check for duplicated values in data :",dup)
# Out:
# check for duplicated values in data : True

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (45175, 15)

# %%
print("total drop duplicated rows is ",45222-45175)
# Out:
# total drop duplicated rows is  47

# %% [markdown]
# # 10 Get overall statistics about the DataFrame

# %%
statistics=data.describe()

# %%
statistics
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
sns.heatmap(data.describe())
# Out:
# <Axes: >

# %% [markdown]
# # 11. Drop The Columns education-num, capital-gain, and capital-loss

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.drop(['educational-num','capital-gain','capital-loss'],axis=1)
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# # 12. What Is The Distribution of Age Column?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
#show age distribution using histogram
data['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # 13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['age'].between(17,48).sum()
# Out:
# 34858

# %% [markdown]
# # 14. What is The Distribution of Workclass Column?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['workclass']
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 45175, dtype: object

# %%
plt.figure(figsize=(15,7))
data['workclass'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # 15. How Many Persons Having Bachelors and Masters Degree?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data['education'].head(30)
# Out:
# 0             11th
# 1          HS-grad
# 2       Assoc-acdm
# 3     Some-college
# 5             10th
# 7      Prof-school
# 8     Some-college
# 9          7th-8th
# 10         HS-grad
# 11       Bachelors
# 12         HS-grad
# 14         HS-grad
# 15         Masters
# 16    Some-college
# 17         HS-grad
# 18         HS-grad
# 20       Bachelors
# 21    Some-college
# 23       Bachelors
# 24       Bachelors
# 25         HS-grad
# 26         HS-grad
# 27         HS-grad
# 28         HS-grad
# 29    Some-college
# 30    Some-college
# 31            11th
# 32       Bachelors
# 33    Some-college
# 34         HS-grad
# Name: education, dtype: object

# %%
data['education'].str.contains('Bachelors',case=False).sum()
# Out:
# 7559

# %%
data['education'].str.contains('Masters', case=False).sum()
# Out:
# 2513

# %%
print("total Persons Having Bachelors and Masters Degree:- ",7559+2513)
# Out:
# total Persons Having Bachelors and Masters Degree:-  10072

# %%
data[data['education'].str.contains('Bachelors',case=False) | data['education'].str.contains('Masters', case=False)]
# Out:
#        age    workclass  fnlwgt  education  educational-num  \
# 11      36  Federal-gov  212465  Bachelors               13
# 15      43      Private  346189    Masters               14
# 20      34      Private  107914  Bachelors               13
# 23      25      Private  220931  Bachelors               13
# 24      25      Private  205947  Bachelors               13
# ...    ...          ...     ...        ...              ...
# 48817   34      Private  160216  Bachelors               13
# 48819   38      Private  139180  Bachelors               13
# 48825   31      Private  199655    Masters               14
# 48834   32      Private  116138    Masters               14
# 48835   53      Private  321865    Masters               14
#
#            marital-status       occupation   relationship                race  \
# 11     Married-civ-spouse     Adm-clerical        Husband               White
# 15     Married-civ-spouse  Exec-managerial        Husband               White
# ...

# %% [markdown]
# # 16. Bivariate Analsis

# %%
#bivariate analsis is use to define relationship between two variables 
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#here data is which data are uou wnat to show 
sns.boxplot(x='income',y='age',data=data)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# # 17. Replace Salary Values[<=50k,50k=>] With 0 and 1

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
def income_check(incomee):
    if incomee=='<=50':
        return 0
    else:
        return 1

# %%
data['enconded_income']=data['income'].apply(income_check)

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
# ...

# %% [markdown]
# # 18. Which Workclass Getting The Highest Salary?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income', 'enconded_income'],
#       dtype='object')

# %%
data[['workclass','income']]
# Out:
#           workclass income
# 0           Private  <=50K
# 1           Private  <=50K
# 2         Local-gov   >50K
# 3           Private   >50K
# 4                 ?  <=50K
# ...             ...    ...
# 48837       Private  <=50K
# 48838       Private   >50K
# 48839       Private  <=50K
# 48840       Private  <=50K
# 48841  Self-emp-inc   >50K
#
# [48842 rows x 2 columns]

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
# 'income' column contains string values like '<=50K' and '>50K', you need to convert them to numeric values first.
data['income'] = data['income'].map({'<=50K': 0, '>50K': 1})
print(data['income'].dtype)
# Out:
# int64

# %%
result = data.groupby('workclass')['income'].mean().sort_values(ascending=False)
result
# Out:
# workclass
# Self-emp-inc        0.553392
# Federal-gov         0.391760
# Local-gov           0.295599
# Self-emp-not-inc    0.278871
# State-gov           0.267542
# Private             0.217867
# Without-pay         0.095238
# ?                   0.094677
# Never-worked        0.000000
# Name: income, dtype: float64

# %% [markdown]
# # 19.How Has Better Chance To Get Salary greater than 50K Male or Female?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.groupby('gender')['income'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.303767
# Female    0.109251
# Name: income, dtype: float64

# %% [markdown]
# # 20. Covert workclass Columns Datatype To Category Datatype

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 5.6+ MB

# %%
data['workclass']
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 4                   ?
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 48842, dtype: object

# %%
data['workclass']=data['workclass'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  category
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  int64
# dtypes: category(1), int64(7), object(7)
# memory usage: 5.3+ MB
